# %% [markdown]
# # Práctica 1: Funciones básicas
# Vas a practicar carga, redimensionado y rotación de imágenes. Si te trabás, repasá la lección en `../notebooks/1_funciones_basicas.ipynb`.

# %% [markdown]
# ### Ejercicio 1: Redimensionar una imagen distinta
# Cargá `img2.jpg` y redimensionala a un tamaño distinto al usado en la lección (por ejemplo 400x300).

# %%
import cv2  # Qué: importa OpenCV, necesario para leer, redimensionar y mostrar la imagen.

image2 = cv2.imread("../imgs/img2.jpg")  # Qué: lee img2.jpg del disco y la decodifica a un array BGR de NumPy, igual que en la lección.

# TODO: redimensioná `image2` a un tamaño de 400x300 píxeles usando cv2.resize
# Pista: cv2.resize acepta una tupla de tamaño fijo (ancho, alto) como segundo argumento, tal como se vio en la lección con (500,500) — acá el objetivo es practicar con dimensiones no cuadradas.
# y guardá el resultado en la variable `resized_image`
resized_image = None  # Placeholder a reemplazar: acá debe quedar la imagen ya redimensionada, no None.

cv2.imshow("Imagen Redimensionada", resized_image)  # Qué: muestra el resultado en una ventana (una vez resuelto el TODO de arriba).
cv2.waitKey(0)  # Qué: espera indefinidamente a que se presione una tecla.
cv2.destroyAllWindows()  # Qué: cierra la ventana para liberar los recursos de GUI.

# %% [markdown]
# ### Ejercicio 2: Rotar la imagen con un ángulo distinto
# Usando `resized_image` del ejercicio anterior, rotala 45 grados (la lección usó 70°).

# %%
import cv2  # Qué: importa OpenCV para calcular la matriz de rotación y aplicarla.

# TODO: obtené alto y ancho de `resized_image` con .shape[:2]
# Pista: .shape devuelve (alto, ancho, canales); necesitás alto y ancho para calcular el centro de la imagen, igual que en la lección.
# y calculá el centro (center) de la imagen
height, width = None, None  # Placeholder a reemplazar: extraer con resized_image.shape[:2].
center = None  # Placeholder a reemplazar: el centro es una tupla (x, y) en píxeles; pensá qué operación aritmética simple sobre width y height te da el punto medio.

# TODO: generá la matriz de rotación con cv2.getRotationMatrix2D
# Pista: la función recibe el punto pivote (center), el ángulo en grados y el factor de escala — acá el ángulo debe ser 45 en vez de los 70 de la lección.
# usando un ángulo de 45 grados
rotation_matrix = None  # Placeholder a reemplazar por la matriz devuelta por cv2.getRotationMatrix2D.

# TODO: aplicá la rotación con cv2.warpAffine sobre `resized_image`
# Pista: warpAffine necesita la imagen, la matriz de rotación y el tamaño de salida (width, height).
rotated_image = None  # Placeholder a reemplazar por el resultado de cv2.warpAffine.

cv2.imshow("Imagen Rotada 45 grados", rotated_image)  # Qué: muestra el resultado en una ventana (una vez resueltos los TODO de arriba).
cv2.waitKey(0)  # Qué: espera indefinidamente a que se presione una tecla.
cv2.destroyAllWindows()  # Qué: cierra la ventana para liberar los recursos de GUI.
