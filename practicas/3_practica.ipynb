# %% [markdown]
# # Práctica 3: Detección de características
# Vas a detectar y comparar keypoints con ORB y SIFT sobre `img1.jpg`. Si te trabás, repasá la lección en `../notebooks/3_deteccion_caracteristicas.ipynb`.

# %% [markdown]
# ### Ejercicio 1: Detectar keypoints con ORB y SIFT
# Detectá los keypoints y descriptores de `img1.jpg` (la lección usó `img2.jpg`) usando ORB y SIFT.

# %%
import cv2  # Qué: importa OpenCV, con los detectores ORB/SIFT y las funciones de dibujo.

image = cv2.imread("../imgs/img1.jpg")  # Qué: carga img1.jpg a color, la imagen sobre la que se detectan los keypoints.
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Qué: convierte a escala de grises, ya que ORB y SIFT trabajan sobre intensidad, no color.

orb = cv2.ORB_create()  # Qué: instancia el detector/descriptor ORB con parámetros por defecto.
sift = cv2.SIFT_create()  # Qué: instancia el detector/descriptor SIFT con parámetros por defecto.

# TODO: calculá keypoints y descriptores con orb.detectAndCompute sobre gray_image
# Pista: detectAndCompute recibe la imagen en gris y una máscara (None si no se quiere restringir la zona de búsqueda), y devuelve dos valores: la lista de keypoints y la matriz de descriptores.
keypointsORB, descriptorsORB = None, None  # Placeholder a reemplazar por la tupla que devuelve orb.detectAndCompute.

# TODO: calculá keypoints y descriptores con sift.detectAndCompute sobre gray_image
# Pista: misma firma que ORB, pero con el objeto sift.
keypointsSIFT, descriptorsSIFT = None, None  # Placeholder a reemplazar por la tupla que devuelve sift.detectAndCompute.

# TODO: dibujá los keypoints de cada detector con cv2.drawKeypoints
# Pista: drawKeypoints recibe la imagen original, la lista de keypoints, un array de salida (None para que cree uno nuevo) y opcionalmente un color.
image_with_keypointsORB = None  # Placeholder a reemplazar por el resultado de cv2.drawKeypoints con los keypoints de ORB.
image_with_keypointsSIFT = None  # Placeholder a reemplazar por el resultado de cv2.drawKeypoints con los keypoints de SIFT.

cv2.imshow("Puntos Clave ORB", image_with_keypointsORB)  # Qué: muestra los keypoints de ORB en una ventana.
cv2.imshow("Puntos Clave SIFT", image_with_keypointsSIFT)  # Qué: muestra los keypoints de SIFT en otra ventana, para comparar.
cv2.waitKey(0)  # Qué: espera indefinidamente a que se presione una tecla.
cv2.destroyAllWindows()  # Qué: cierra las ventanas para liberar los recursos de GUI.

# %% [markdown]
# ### Ejercicio 2: Comparar la cantidad de keypoints
# Contá cuántos keypoints detectó cada algoritmo con `len(...)` y compará los resultados.

# %%
# TODO: contá cuántos keypoints detectó ORB usando len(keypointsORB)
# Pista: keypointsORB es una lista de objetos KeyPoint; len() te da directamente la cantidad de puntos detectados.
cantidad_orb = None  # Placeholder a reemplazar por len(keypointsORB).

# TODO: contá cuántos keypoints detectó SIFT usando len(keypointsSIFT)
# Pista: misma idea que arriba pero sobre keypointsSIFT.
cantidad_sift = None  # Placeholder a reemplazar por len(keypointsSIFT).

print(f"ORB detecto {cantidad_orb} keypoints")  # Qué: imprime la cantidad de keypoints detectados por ORB usando un f-string.
print(f"SIFT detecto {cantidad_sift} keypoints")  # Qué: imprime la cantidad de keypoints detectados por SIFT.

# TODO: agregá un print que indique cuál de los dos detectó más keypoints
# Pista: comparás cantidad_orb y cantidad_sift con un condicional y armás un mensaje según cuál sea mayor (o si empatan).
