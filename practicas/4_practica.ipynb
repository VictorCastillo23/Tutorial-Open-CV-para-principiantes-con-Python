# %% [markdown]
# # Práctica 4: Transformaciones geométricas
# Vas a definir un nuevo cuadrilátero y aplicar una transformación de perspectiva sobre `img1.jpg`. Si te trabás, repasá la lección en `../notebooks/4_transformaciones_geometricas.ipynb`.

# %% [markdown]
# ### Ejercicio 1: Definir un nuevo cuadrilátero
# Definí 4 puntos distintos a los de la lección sobre `img1.jpg` (la lección usó `img2.jpg`).

# %%
import cv2  # Qué: importa OpenCV para leer la imagen y luego calcular/aplicar la transformación de perspectiva.
import numpy as np  # Qué: importa NumPy porque los puntos pts1/pts2 deben construirse como arrays float32.

image = cv2.imread("../imgs/img1.jpg")  # Qué: carga img1.jpg a color, la imagen sobre la que se va a aplicar la nueva perspectiva.

# TODO: definí pts1, un cuadrilátero de 4 puntos distinto al de la lección
# Pista: son 4 coordenadas (x, y) en np.float32, como en la lección; probá usar puntos que no formen un cuadrado perfecto para variar el ejercicio.
# (la lección usó [[50, 50], [200, 50], [50, 200], [200, 200]])
pts1 = None  # Placeholder a reemplazar por un np.float32 con 4 puntos de origen.

# TODO: definí pts2, la nueva ubicación de esos 4 puntos en la imagen transformada
# Pista: cada punto de pts2 debe corresponder en orden al mismo índice de pts1 (primero con primero, etc.).
pts2 = None  # Placeholder a reemplazar por un np.float32 con 4 puntos de destino.

# %% [markdown]
# ### Ejercicio 2: Aplicar la transformación de perspectiva
# Calculá la matriz de transformación con `pts1` y `pts2`, y aplicala sobre `img1.jpg`.

# %%
# TODO: obtené la matriz de transformación con cv2.getPerspectiveTransform(pts1, pts2)
# Pista: la función devuelve la matriz de homografía 3x3 que mapea pts1 a pts2.
perspective_matrix = None  # Placeholder a reemplazar por el resultado de cv2.getPerspectiveTransform.

height, width = image.shape[:2]  # Qué: extrae alto y ancho de la imagen original para usarlos como tamaño de salida de la transformación.

# TODO: aplicá cv2.warpPerspective sobre `image` usando perspective_matrix
# Pista: warpPerspective recibe la imagen, la matriz y el tamaño de salida (ancho, alto) — prestá atención al orden de width/height.
transformed_image = None  # Placeholder a reemplazar por el resultado de cv2.warpPerspective.

cv2.imshow("Imagen con Nueva Perspectiva", transformed_image)  # Qué: muestra el resultado en una ventana (una vez resueltos los TODO de arriba).
cv2.waitKey(0)  # Qué: espera indefinidamente a que se presione una tecla.
cv2.destroyAllWindows()  # Qué: cierra la ventana para liberar los recursos de GUI.
